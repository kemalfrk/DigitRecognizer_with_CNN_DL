# %% [markdown]
# <a href="https://colab.research.google.com/github/kemalfrk/DigitRecognizer_with_CNN_DL/blob/master/fillna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#Bir dataframe oluşturalım
df=pd.DataFrame({'A':[1,2,3,4,5,np.nan,7,np.nan,9,np.nan],
                 'B':[10,20,np.nan,30,40,50,np.nan,70,80,np.nan]}
                )

# %%
df
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0   NaN
# 3  4.0  30.0
# 4  5.0  40.0
# 5  NaN  50.0
# 6  7.0   NaN
# 7  NaN  70.0
# 8  9.0  80.0
# 9  NaN   NaN

# %%
#her bir işlem için datframemimde boşluklar dolacağı için dataframemimin kopyasını oluşturuyorum.
df1=df.copy()

# %%
df1.info() #dataframe.info ile kolonlarımın veri tipleri ve boş satır bilgilerimi öğreniyorum.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       7 non-null      float64
#  1   B       7 non-null      float64
# dtypes: float64(2)
# memory usage: 288.0 bytes

# %%
df1.isnull() #satır bazlı boş değerlerime bakıyorum True olanlar boş değerler oluyor.
# Out:
#        A      B
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False  False
# 5   True  False
# 6  False   True
# 7   True  False
# 8  False  False
# 9   True   True

# %%
df1.isnull().sum() #burada da her bir kolonumda kaç tane boş değer var ona baktım
# Out:
# A    3
# B    3
# dtype: int64

# %% [markdown]
# # Ortalama ile eksik verileri doldurma

# %%
df['A'].mean() #A kolonumuzun dolu olan değerlerinin ortalamasına bakıyorum ki boş verilerimi onunla doldurulacağı için
# Out:
# 4.428571428571429

# %%
df1['A']=df1['A'].fillna(df1['A'].mean())

# %%
df1['A']
# Out:
# 0    1.000000
# 1    2.000000
# 2    3.000000
# 3    4.000000
# 4    5.000000
# 5    4.428571
# 6    7.000000
# 7    4.428571
# 8    9.000000
# 9    4.428571
# Name: A, dtype: float64

# %%
df1
# Out:
#           A     B
# 0  1.000000  10.0
# 1  2.000000  20.0
# 2  3.000000   NaN
# 3  4.000000  30.0
# 4  5.000000  40.0
# 5  4.428571  50.0
# 6  7.000000   NaN
# 7  4.428571  70.0
# 8  9.000000  80.0
# 9  4.428571   NaN

# %%
df1['B'].mean() #B kolonumuzun dolu olan değerlerinin ortalamasına bakıyorum ki boş verilerimi onunla doldurulacağı için
# Out:
# 42.857142857142854

# %%
df1['B']=df1['B'].fillna(df1['B'].mean())

# %%
df1
# Out:
#           A          B
# 0  1.000000  10.000000
# 1  2.000000  20.000000
# 2  3.000000  42.857143
# 3  4.000000  30.000000
# 4  5.000000  40.000000
# 5  4.428571  50.000000
# 6  7.000000  42.857143
# 7  4.428571  70.000000
# 8  9.000000  80.000000
# 9  4.428571  42.857143

# %% [markdown]
# # Medyan ile eksik verilerin doldurulması

# %%
df2=df.copy() #df1 in boş verilerini doldurduğum için yeni bir df kopyamı oluşturuyorum.

# %%
df2
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0   NaN
# 3  4.0  30.0
# 4  5.0  40.0
# 5  NaN  50.0
# 6  7.0   NaN
# 7  NaN  70.0
# 8  9.0  80.0
# 9  NaN   NaN

# %%
df2['A'].median() #A kolonumuzun medyanına baktım onunla dolduracağım için
# Out:
# 4.0

# %%
df2['A']=df2['A'].fillna(df2['A'].median())

# %%
df2['A']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    4.0
# 6    7.0
# 7    4.0
# 8    9.0
# 9    4.0
# Name: A, dtype: float64

# %%
df2['B'].median()
# Out:
# 40.0

# %%
df2['B']=df2['B'].fillna(df2['B'].median())

# %%
df2['B']
# Out:
# 0    10.0
# 1    20.0
# 2    40.0
# 3    30.0
# 4    40.0
# 5    50.0
# 6    40.0
# 7    70.0
# 8    80.0
# 9    40.0
# Name: B, dtype: float64

# %% [markdown]
# #  Eksik verilerin bir önceki ile doldurulması

# %%
df3=df.copy()
df3 #yeniden bir dataframe kopyası oluşturuyorum.
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0   NaN
# 3  4.0  30.0
# 4  5.0  40.0
# 5  NaN  50.0
# 6  7.0   NaN
# 7  NaN  70.0
# 8  9.0  80.0
# 9  NaN   NaN

# %%
df3['A']=df3['A'].fillna(method='ffill')
df3['A']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    5.0
# 6    7.0
# 7    7.0
# 8    9.0
# 9    9.0
# Name: A, dtype: float64

# %%
df3['B']=df3['B'].fillna(method='ffill')
df3['B']
# Out:
# 0    10.0
# 1    20.0
# 2    20.0
# 3    30.0
# 4    40.0
# 5    50.0
# 6    50.0
# 7    70.0
# 8    80.0
# 9    80.0
# Name: B, dtype: float64

# %%
df3
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0  20.0
# 3  4.0  30.0
# 4  5.0  40.0
# 5  5.0  50.0
# 6  7.0  50.0
# 7  7.0  70.0
# 8  9.0  80.0
# 9  9.0  80.0

# %% [markdown]
# # **Bir Sonraki ile Doldurma**

# %%
df4=df.copy()
df4 #dataframe kopyası oluşturuyoruz yeniden
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0   NaN
# 3  4.0  30.0
# 4  5.0  40.0
# 5  NaN  50.0
# 6  7.0   NaN
# 7  NaN  70.0
# 8  9.0  80.0
# 9  NaN   NaN

# %%
df4['A']=df4['A'].fillna(method='bfill')
df4['A']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    7.0
# 6    7.0
# 7    9.0
# 8    9.0
# 9    NaN
# Name: A, dtype: float64

# %%
df4['B']=df4['B'].fillna(method='bfill')
df4['B']
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    30.0
# 4    40.0
# 5    50.0
# 6    70.0
# 7    70.0
# 8    80.0
# 9     NaN
# Name: B, dtype: float64

# %%
df4
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0  30.0
# 3  4.0  30.0
# 4  5.0  40.0
# 5  7.0  50.0
# 6  7.0  70.0
# 7  9.0  70.0
# 8  9.0  80.0
# 9  NaN   NaN

# %% [markdown]
# Gördüğünüz gibi bir sonraki değerle doldurduğumuzda dataframin son rowları hala nan kaldı bunu düzeltmemiz için aynı zamanda bir önceki ile doldurma uygulamamız lazım

# %%
df4.fillna(method='ffill',inplace=True)

# %%
df4
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0  30.0
# 3  4.0  30.0
# 4  5.0  40.0
# 5  7.0  50.0
# 6  7.0  70.0
# 7  9.0  70.0
# 8  9.0  80.0
# 9  9.0  80.0

# %% [markdown]
# Gördüğünüz gibi bir önceki ile doldurma metodunu uyguladığımızda doldurulmuş oldu

# %% [markdown]
# # **SimpleImputer ile doldurma**

# %%
df5=df.copy()
df5 #dataframe kopyası oluşturuyoruz
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0   NaN
# 3  4.0  30.0
# 4  5.0  40.0
# 5  NaN  50.0
# 6  7.0   NaN
# 7  NaN  70.0
# 8  9.0  80.0
# 9  NaN   NaN

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# ### Method: ortalama ile

# %%
imp=SimpleImputer(missing_values=np.nan,strategy='mean')
df5['A']=imp.fit_transform(df5[['A']])
df5['A']
# Out:
# 0    1.000000
# 1    2.000000
# 2    3.000000
# 3    4.000000
# 4    5.000000
# 5    4.428571
# 6    7.000000
# 7    4.428571
# 8    9.000000
# 9    4.428571
# Name: A, dtype: float64

# %%
imp=SimpleImputer(missing_values=np.nan,strategy='mean')
df5['B']=imp.fit_transform(df5[['B']])
df5['B']
# Out:
# 0    10.000000
# 1    20.000000
# 2    42.857143
# 3    30.000000
# 4    40.000000
# 5    50.000000
# 6    42.857143
# 7    70.000000
# 8    80.000000
# 9    42.857143
# Name: B, dtype: float64

# %%
df5
# Out:
#           A          B
# 0  1.000000  10.000000
# 1  2.000000  20.000000
# 2  3.000000  42.857143
# 3  4.000000  30.000000
# 4  5.000000  40.000000
# 5  4.428571  50.000000
# 6  7.000000  42.857143
# 7  4.428571  70.000000
# 8  9.000000  80.000000
# 9  4.428571  42.857143

# %% [markdown]
# ### Method: Medyan ile

# %%
df6=df.copy()
df6
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0   NaN
# 3  4.0  30.0
# 4  5.0  40.0
# 5  NaN  50.0
# 6  7.0   NaN
# 7  NaN  70.0
# 8  9.0  80.0
# 9  NaN   NaN

# %%
imp=SimpleImputer(missing_values=np.nan,strategy='median')
df6['A']=imp.fit_transform(df6[['A']])
df6['A']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    4.0
# 6    7.0
# 7    4.0
# 8    9.0
# 9    4.0
# Name: A, dtype: float64

# %%
imp=SimpleImputer(missing_values=np.nan,strategy='median')
df6['B']=imp.fit_transform(df6[['B']])
df6['B']
# Out:
# 0    10.0
# 1    20.0
# 2    40.0
# 3    30.0
# 4    40.0
# 5    50.0
# 6    40.0
# 7    70.0
# 8    80.0
# 9    40.0
# Name: B, dtype: float64

# %%
df6
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0  40.0
# 3  4.0  30.0
# 4  5.0  40.0
# 5  4.0  50.0
# 6  7.0  40.0
# 7  4.0  70.0
# 8  9.0  80.0
# 9  4.0  40.0

# %% [markdown]
# ### Peki Verimizde Kategorik Değişkenler kolonunda Eksik Veri Varsa Nasıl Yapmalıyız

# %%
data=pd.DataFrame({'A':["İstanbul","Ankara","İstanbul","İzmir","Ankara","İstanbul",np.nan,"Bartın","İstanbul",np.nan,"İstanbul",np.nan],
                   'B':np.random.randint(0, 100, size=12)})

# %%
data
# Out:
#            A   B
# 0   İstanbul  65
# 1     Ankara  60
# 2   İstanbul  18
# 3      İzmir  53
# 4     Ankara  69
# 5   İstanbul  98
# 6        NaN  86
# 7     Bartın  61
# 8   İstanbul  43
# 9        NaN  22
# 10  İstanbul  28
# 11       NaN  67

# %%
df['A'].isnull().sum()
# Out:
# 3

# %%
data = pd.DataFrame({
    'A': ["Istanbul", "Ankara", "Istanbul", "Izmir", "Ankara", "Istanbul", np.nan, "Bartın", "Istanbul", np.nan, "Elazığ", np.nan],
    'B': np.random.randint(0, 100, size=12)
})



# SimpleImputer ile eksik değerleri en sık görülen değerle doldurma
imp = SimpleImputer(strategy='most_frequent')
# fit_transform 2B bir dizi döndürür, bu nedenle bunu 1B'ye düzleştirmemiz gerekir
data['A'] = imp.fit_transform(data[['A']]).ravel()

data
# Out:
#            A   B
# 0   Istanbul  11
# 1     Ankara  66
# 2   Istanbul  44
# 3      Izmir  84
# 4     Ankara  67
# 5   Istanbul  78
# 6   Istanbul  32
# 7     Bartın  13
# 8   Istanbul  37
# 9   Istanbul  35
# 10    Elazığ  12
# 11  Istanbul  13
